# %%
from p5 import *

def setup():
    size(400, 300)
    background(255)
    
def draw():
    stroke(10, 255, 200)
    fill(255, 100, 100)
    
    point(200, 200)
    line((10, 240), (110, 240))
    rect((10, 20) , 100, 200)
    ellipse((310, 50), 50, 50)
    
run()
# Out:
# ---------------------------------------------------------------------------
# GLError                                   Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# c:\program files\python35\lib\site-packages\pyglet\app\win32.py in _timer_proc_func(self, hwnd, msg, timer, t)
#     146     def _timer_proc_func(self, hwnd, msg, timer, t):
#     147         if self._timer_func:
# --> 148             self._timer_func()
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in _blocking_timer(self)
#     243
#     244     def _blocking_timer(self):
# --> 245         timeout = self.idle()
#     246         app.platform_event_loop.set_timer(self._blocking_timer, timeout)
#     247
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in idle(self)
#     272         '''
#     273         dt = self.clock.update_time()
# --> 274         redraw_all = self.clock.call_scheduled_functions(dt)
#     275
#     276         # Redraw all windows
#
# c:\program files\python35\lib\site-packages\pyglet\clock.py in call_scheduled_functions(self, dt)
#     307                 break
#     308             result = True
# --> 309             item.func(ts - item.last_ts, *item.args, **item.kwargs)
#     310             if item.interval:
#     311                 # Try to keep timing regular, even if overslept this time;
#
# c:\program files\python35\lib\site-packages\p5\sketch\base.py in update(dt)
#     218     global last_recorded_time
#     219
# --> 220     with renderer.draw_loop():
#     221         if looping or redraw:
#     222             builtins.frame_count += 1
#
# c:\program files\python35\lib\contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# c:\program files\python35\lib\site-packages\p5\opengl\renderer.py in draw_loop()
#     277     """
#     278     global transform_matrix
# --> 279     gl.glViewport(*viewport)
#     280     transform_matrix = np.identity(4)
#     281
#
# c:\program files\python35\lib\site-packages\OpenGL\error.py in glCheckError(self, result, baseOperation, cArguments, *args)
#     230                         result,
#     231                         cArguments = cArguments,
# --> 232                         baseOperation = baseOperation,
#     233                     )
#     234                 return result
#
# GLError: GLError(
# 	err = 1282,
# 	description = b'invalid operation',
# 	baseOperation = glViewport,
# 	cArguments = (0, 0, 400, 300)
# )
# ---------------------------------------------------------------------------
# GLError                                   Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# c:\program files\python35\lib\site-packages\pyglet\app\win32.py in _timer_proc_func(self, hwnd, msg, timer, t)
#     146     def _timer_proc_func(self, hwnd, msg, timer, t):
#     147         if self._timer_func:
# --> 148             self._timer_func()
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in _blocking_timer(self)
#     243
#     244     def _blocking_timer(self):
# --> 245         timeout = self.idle()
#     246         app.platform_event_loop.set_timer(self._blocking_timer, timeout)
#     247
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in idle(self)
#     272         '''
#     273         dt = self.clock.update_time()
# --> 274         redraw_all = self.clock.call_scheduled_functions(dt)
#     275
#     276         # Redraw all windows
#
# c:\program files\python35\lib\site-packages\pyglet\clock.py in call_scheduled_functions(self, dt)
#     307                 break
#     308             result = True
# --> 309             item.func(ts - item.last_ts, *item.args, **item.kwargs)
#     310             if item.interval:
#     311                 # Try to keep timing regular, even if overslept this time;
#
# c:\program files\python35\lib\site-packages\p5\sketch\base.py in update(dt)
#     218     global last_recorded_time
#     219
# --> 220     with renderer.draw_loop():
#     221         if looping or redraw:
#     222             builtins.frame_count += 1
#
# c:\program files\python35\lib\contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# c:\program files\python35\lib\site-packages\p5\opengl\renderer.py in draw_loop()
#     277     """
#     278     global transform_matrix
# --> 279     gl.glViewport(*viewport)
#     280     transform_matrix = np.identity(4)
#     281
#
# c:\program files\python35\lib\site-packages\OpenGL\error.py in glCheckError(self, result, baseOperation, cArguments, *args)
#     230                         result,
#     231                         cArguments = cArguments,
# --> 232                         baseOperation = baseOperation,
#     233                     )
#     234                 return result
#
# GLError: GLError(
# 	err = 1282,
# 	description = b'invalid operation',
# 	baseOperation = glViewport,
# 	cArguments = (0, 0, 400, 300)
# )
# ---------------------------------------------------------------------------
# GLError                                   Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# c:\program files\python35\lib\site-packages\pyglet\app\win32.py in _timer_proc_func(self, hwnd, msg, timer, t)
#     146     def _timer_proc_func(self, hwnd, msg, timer, t):
#     147         if self._timer_func:
# --> 148             self._timer_func()
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in _blocking_timer(self)
#     243
#     244     def _blocking_timer(self):
# --> 245         timeout = self.idle()
#     246         app.platform_event_loop.set_timer(self._blocking_timer, timeout)
#     247
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in idle(self)
#     272         '''
#     273         dt = self.clock.update_time()
# --> 274         redraw_all = self.clock.call_scheduled_functions(dt)
#     275
#     276         # Redraw all windows
#
# c:\program files\python35\lib\site-packages\pyglet\clock.py in call_scheduled_functions(self, dt)
#     307                 break
#     308             result = True
# --> 309             item.func(ts - item.last_ts, *item.args, **item.kwargs)
#     310             if item.interval:
#     311                 # Try to keep timing regular, even if overslept this time;
#
# c:\program files\python35\lib\site-packages\p5\sketch\base.py in update(dt)
#     218     global last_recorded_time
#     219
# --> 220     with renderer.draw_loop():
#     221         if looping or redraw:
#     222             builtins.frame_count += 1
#
# c:\program files\python35\lib\contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# c:\program files\python35\lib\site-packages\p5\opengl\renderer.py in draw_loop()
#     277     """
#     278     global transform_matrix
# --> 279     gl.glViewport(*viewport)
#     280     transform_matrix = np.identity(4)
#     281
#
# c:\program files\python35\lib\site-packages\OpenGL\error.py in glCheckError(self, result, baseOperation, cArguments, *args)
#     230                         result,
#     231                         cArguments = cArguments,
# --> 232                         baseOperation = baseOperation,
#     233                     )
#     234                 return result
#
# GLError: GLError(
# 	err = 1282,
# 	description = b'invalid operation',
# 	baseOperation = glViewport,
# 	cArguments = (0, 0, 400, 300)
# )
# ---------------------------------------------------------------------------
# GLError                                   Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# c:\program files\python35\lib\site-packages\pyglet\app\win32.py in _timer_proc_func(self, hwnd, msg, timer, t)
#     146     def _timer_proc_func(self, hwnd, msg, timer, t):
#     147         if self._timer_func:
# --> 148             self._timer_func()
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in _blocking_timer(self)
#     243
#     244     def _blocking_timer(self):
# --> 245         timeout = self.idle()
#     246         app.platform_event_loop.set_timer(self._blocking_timer, timeout)
#     247
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in idle(self)
#     272         '''
#     273         dt = self.clock.update_time()
# --> 274         redraw_all = self.clock.call_scheduled_functions(dt)
#     275
#     276         # Redraw all windows
#
# c:\program files\python35\lib\site-packages\pyglet\clock.py in call_scheduled_functions(self, dt)
#     307                 break
#     308             result = True
# --> 309             item.func(ts - item.last_ts, *item.args, **item.kwargs)
#     310             if item.interval:
#     311                 # Try to keep timing regular, even if overslept this time;
#
# c:\program files\python35\lib\site-packages\p5\sketch\base.py in update(dt)
#     218     global last_recorded_time
#     219
# --> 220     with renderer.draw_loop():
#     221         if looping or redraw:
#     222             builtins.frame_count += 1
#
# c:\program files\python35\lib\contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# c:\program files\python35\lib\site-packages\p5\opengl\renderer.py in draw_loop()
#     277     """
#     278     global transform_matrix
# --> 279     gl.glViewport(*viewport)
#     280     transform_matrix = np.identity(4)
#     281
#
# c:\program files\python35\lib\site-packages\OpenGL\error.py in glCheckError(self, result, baseOperation, cArguments, *args)
#     230                         result,
#     231                         cArguments = cArguments,
# --> 232                         baseOperation = baseOperation,
#     233                     )
#     234                 return result
#
# GLError: GLError(
# 	err = 1282,
# 	description = b'invalid operation',
# 	baseOperation = glViewport,
# 	cArguments = (0, 0, 400, 300)
# )
# ---------------------------------------------------------------------------
# GLError                                   Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# c:\program files\python35\lib\site-packages\pyglet\app\win32.py in _timer_proc_func(self, hwnd, msg, timer, t)
#     146     def _timer_proc_func(self, hwnd, msg, timer, t):
#     147         if self._timer_func:
# --> 148             self._timer_func()
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in _blocking_timer(self)
#     243
#     244     def _blocking_timer(self):
# --> 245         timeout = self.idle()
#     246         app.platform_event_loop.set_timer(self._blocking_timer, timeout)
#     247
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in idle(self)
#     272         '''
#     273         dt = self.clock.update_time()
# --> 274         redraw_all = self.clock.call_scheduled_functions(dt)
#     275
#     276         # Redraw all windows
#
# c:\program files\python35\lib\site-packages\pyglet\clock.py in call_scheduled_functions(self, dt)
#     307                 break
#     308             result = True
# --> 309             item.func(ts - item.last_ts, *item.args, **item.kwargs)
#     310             if item.interval:
#     311                 # Try to keep timing regular, even if overslept this time;
#
# c:\program files\python35\lib\site-packages\p5\sketch\base.py in update(dt)
#     218     global last_recorded_time
#     219
# --> 220     with renderer.draw_loop():
#     221         if looping or redraw:
#     222             builtins.frame_count += 1
#
# c:\program files\python35\lib\contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# c:\program files\python35\lib\site-packages\p5\opengl\renderer.py in draw_loop()
#     277     """
#     278     global transform_matrix
# --> 279     gl.glViewport(*viewport)
#     280     transform_matrix = np.identity(4)
#     281
#
# c:\program files\python35\lib\site-packages\OpenGL\error.py in glCheckError(self, result, baseOperation, cArguments, *args)
#     230                         result,
#     231                         cArguments = cArguments,
# --> 232                         baseOperation = baseOperation,
#     233                     )
#     234                 return result
#
# GLError: GLError(
# 	err = 1282,
# 	description = b'invalid operation',
# 	baseOperation = glViewport,
# 	cArguments = (0, 0, 400, 300)
# )
# ---------------------------------------------------------------------------
# GLError                                   Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# c:\program files\python35\lib\site-packages\pyglet\app\win32.py in _timer_proc_func(self, hwnd, msg, timer, t)
#     146     def _timer_proc_func(self, hwnd, msg, timer, t):
#     147         if self._timer_func:
# --> 148             self._timer_func()
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in _blocking_timer(self)
#     243
#     244     def _blocking_timer(self):
# --> 245         timeout = self.idle()
#     246         app.platform_event_loop.set_timer(self._blocking_timer, timeout)
#     247
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in idle(self)
#     272         '''
#     273         dt = self.clock.update_time()
# --> 274         redraw_all = self.clock.call_scheduled_functions(dt)
#     275
#     276         # Redraw all windows
#
# c:\program files\python35\lib\site-packages\pyglet\clock.py in call_scheduled_functions(self, dt)
#     307                 break
#     308             result = True
# --> 309             item.func(ts - item.last_ts, *item.args, **item.kwargs)
#     310             if item.interval:
#     311                 # Try to keep timing regular, even if overslept this time;
#
# c:\program files\python35\lib\site-packages\p5\sketch\base.py in update(dt)
#     218     global last_recorded_time
#     219
# --> 220     with renderer.draw_loop():
#     221         if looping or redraw:
#     222             builtins.frame_count += 1
#
# c:\program files\python35\lib\contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# c:\program files\python35\lib\site-packages\p5\opengl\renderer.py in draw_loop()
#     277     """
#     278     global transform_matrix
# --> 279     gl.glViewport(*viewport)
#     280     transform_matrix = np.identity(4)
#     281
#
# c:\program files\python35\lib\site-packages\OpenGL\error.py in glCheckError(self, result, baseOperation, cArguments, *args)
#     230                         result,
#     231                         cArguments = cArguments,
# --> 232                         baseOperation = baseOperation,
#     233                     )
#     234                 return result
#
# GLError: GLError(
# 	err = 1282,
# 	description = b'invalid operation',
# 	baseOperation = glViewport,
# 	cArguments = (0, 0, 400, 300)
# )
# ---------------------------------------------------------------------------
# GLError                                   Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# c:\program files\python35\lib\site-packages\pyglet\app\win32.py in _timer_proc_func(self, hwnd, msg, timer, t)
#     146     def _timer_proc_func(self, hwnd, msg, timer, t):
#     147         if self._timer_func:
# --> 148             self._timer_func()
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in _blocking_timer(self)
#     243
#     244     def _blocking_timer(self):
# --> 245         timeout = self.idle()
#     246         app.platform_event_loop.set_timer(self._blocking_timer, timeout)
#     247
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in idle(self)
#     272         '''
#     273         dt = self.clock.update_time()
# --> 274         redraw_all = self.clock.call_scheduled_functions(dt)
#     275
#     276         # Redraw all windows
#
# c:\program files\python35\lib\site-packages\pyglet\clock.py in call_scheduled_functions(self, dt)
#     307                 break
#     308             result = True
# --> 309             item.func(ts - item.last_ts, *item.args, **item.kwargs)
#     310             if item.interval:
#     311                 # Try to keep timing regular, even if overslept this time;
#
# c:\program files\python35\lib\site-packages\p5\sketch\base.py in update(dt)
#     218     global last_recorded_time
#     219
# --> 220     with renderer.draw_loop():
#     221         if looping or redraw:
#     222             builtins.frame_count += 1
#
# c:\program files\python35\lib\contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# c:\program files\python35\lib\site-packages\p5\opengl\renderer.py in draw_loop()
#     277     """
#     278     global transform_matrix
# --> 279     gl.glViewport(*viewport)
#     280     transform_matrix = np.identity(4)
#     281
#
# c:\program files\python35\lib\site-packages\OpenGL\error.py in glCheckError(self, result, baseOperation, cArguments, *args)
#     230                         result,
#     231                         cArguments = cArguments,
# --> 232                         baseOperation = baseOperation,
#     233                     )
#     234                 return result
#
# GLError: GLError(
# 	err = 1282,
# 	description = b'invalid operation',
# 	baseOperation = glViewport,
# 	cArguments = (0, 0, 400, 300)
# )
# ---------------------------------------------------------------------------
# GLError                                   Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# c:\program files\python35\lib\site-packages\pyglet\app\win32.py in _timer_proc_func(self, hwnd, msg, timer, t)
#     146     def _timer_proc_func(self, hwnd, msg, timer, t):
#     147         if self._timer_func:
# --> 148             self._timer_func()
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in _blocking_timer(self)
#     243
#     244     def _blocking_timer(self):
# --> 245         timeout = self.idle()
#     246         app.platform_event_loop.set_timer(self._blocking_timer, timeout)
#     247
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in idle(self)
#     272         '''
#     273         dt = self.clock.update_time()
# --> 274         redraw_all = self.clock.call_scheduled_functions(dt)
#     275
#     276         # Redraw all windows
#
# c:\program files\python35\lib\site-packages\pyglet\clock.py in call_scheduled_functions(self, dt)
#     307                 break
#     308             result = True
# --> 309             item.func(ts - item.last_ts, *item.args, **item.kwargs)
#     310             if item.interval:
#     311                 # Try to keep timing regular, even if overslept this time;
#
# c:\program files\python35\lib\site-packages\p5\sketch\base.py in update(dt)
#     218     global last_recorded_time
#     219
# --> 220     with renderer.draw_loop():
#     221         if looping or redraw:
#     222             builtins.frame_count += 1
#
# c:\program files\python35\lib\contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# c:\program files\python35\lib\site-packages\p5\opengl\renderer.py in draw_loop()
#     277     """
#     278     global transform_matrix
# --> 279     gl.glViewport(*viewport)
#     280     transform_matrix = np.identity(4)
#     281
#
# c:\program files\python35\lib\site-packages\OpenGL\error.py in glCheckError(self, result, baseOperation, cArguments, *args)
#     230                         result,
#     231                         cArguments = cArguments,
# --> 232                         baseOperation = baseOperation,
#     233                     )
#     234                 return result
#
# GLError: GLError(
# 	err = 1282,
# 	description = b'invalid operation',
# 	baseOperation = glViewport,
# 	cArguments = (0, 0, 400, 300)
# )
# ---------------------------------------------------------------------------
# GLError                                   Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# c:\program files\python35\lib\site-packages\pyglet\app\win32.py in _timer_proc_func(self, hwnd, msg, timer, t)
#     146     def _timer_proc_func(self, hwnd, msg, timer, t):
#     147         if self._timer_func:
# --> 148             self._timer_func()
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in _blocking_timer(self)
#     243
#     244     def _blocking_timer(self):
# --> 245         timeout = self.idle()
#     246         app.platform_event_loop.set_timer(self._blocking_timer, timeout)
#     247
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in idle(self)
#     272         '''
#     273         dt = self.clock.update_time()
# --> 274         redraw_all = self.clock.call_scheduled_functions(dt)
#     275
#     276         # Redraw all windows
#
# c:\program files\python35\lib\site-packages\pyglet\clock.py in call_scheduled_functions(self, dt)
#     307                 break
#     308             result = True
# --> 309             item.func(ts - item.last_ts, *item.args, **item.kwargs)
#     310             if item.interval:
#     311                 # Try to keep timing regular, even if overslept this time;
#
# c:\program files\python35\lib\site-packages\p5\sketch\base.py in update(dt)
#     218     global last_recorded_time
#     219
# --> 220     with renderer.draw_loop():
#     221         if looping or redraw:
#     222             builtins.frame_count += 1
#
# c:\program files\python35\lib\contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# c:\program files\python35\lib\site-packages\p5\opengl\renderer.py in draw_loop()
#     277     """
#     278     global transform_matrix
# --> 279     gl.glViewport(*viewport)
#     280     transform_matrix = np.identity(4)
#     281
#
# c:\program files\python35\lib\site-packages\OpenGL\error.py in glCheckError(self, result, baseOperation, cArguments, *args)
#     230                         result,
#     231                         cArguments = cArguments,
# --> 232                         baseOperation = baseOperation,
#     233                     )
#     234                 return result
#
# GLError: GLError(
# 	err = 1282,
# 	description = b'invalid operation',
# 	baseOperation = glViewport,
# 	cArguments = (0, 0, 400, 300)
# )
# ---------------------------------------------------------------------------
# GLError                                   Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# c:\program files\python35\lib\site-packages\pyglet\app\win32.py in _timer_proc_func(self, hwnd, msg, timer, t)
#     146     def _timer_proc_func(self, hwnd, msg, timer, t):
#     147         if self._timer_func:
# --> 148             self._timer_func()
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in _blocking_timer(self)
#     243
#     244     def _blocking_timer(self):
# --> 245         timeout = self.idle()
#     246         app.platform_event_loop.set_timer(self._blocking_timer, timeout)
#     247
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in idle(self)
#     272         '''
#     273         dt = self.clock.update_time()
# --> 274         redraw_all = self.clock.call_scheduled_functions(dt)
#     275
#     276         # Redraw all windows
#
# c:\program files\python35\lib\site-packages\pyglet\clock.py in call_scheduled_functions(self, dt)
#     307                 break
#     308             result = True
# --> 309             item.func(ts - item.last_ts, *item.args, **item.kwargs)
#     310             if item.interval:
#     311                 # Try to keep timing regular, even if overslept this time;
#
# c:\program files\python35\lib\site-packages\p5\sketch\base.py in update(dt)
#     218     global last_recorded_time
#     219
# --> 220     with renderer.draw_loop():
#     221         if looping or redraw:
#     222             builtins.frame_count += 1
#
# c:\program files\python35\lib\contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# c:\program files\python35\lib\site-packages\p5\opengl\renderer.py in draw_loop()
#     277     """
#     278     global transform_matrix
# --> 279     gl.glViewport(*viewport)
#     280     transform_matrix = np.identity(4)
#     281
#
# c:\program files\python35\lib\site-packages\OpenGL\error.py in glCheckError(self, result, baseOperation, cArguments, *args)
#     230                         result,
#     231                         cArguments = cArguments,
# --> 232                         baseOperation = baseOperation,
#     233                     )
#     234                 return result
#
# GLError: GLError(
# 	err = 1282,
# 	description = b'invalid operation',
# 	baseOperation = glViewport,
# 	cArguments = (0, 0, 400, 300)
# )
# ---------------------------------------------------------------------------
# GLError                                   Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# c:\program files\python35\lib\site-packages\pyglet\app\win32.py in _timer_proc_func(self, hwnd, msg, timer, t)
#     146     def _timer_proc_func(self, hwnd, msg, timer, t):
#     147         if self._timer_func:
# --> 148             self._timer_func()
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in _blocking_timer(self)
#     243
#     244     def _blocking_timer(self):
# --> 245         timeout = self.idle()
#     246         app.platform_event_loop.set_timer(self._blocking_timer, timeout)
#     247
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in idle(self)
#     272         '''
#     273         dt = self.clock.update_time()
# --> 274         redraw_all = self.clock.call_scheduled_functions(dt)
#     275
#     276         # Redraw all windows
#
# c:\program files\python35\lib\site-packages\pyglet\clock.py in call_scheduled_functions(self, dt)
#     307                 break
#     308             result = True
# --> 309             item.func(ts - item.last_ts, *item.args, **item.kwargs)
#     310             if item.interval:
#     311                 # Try to keep timing regular, even if overslept this time;
#
# c:\program files\python35\lib\site-packages\p5\sketch\base.py in update(dt)
#     218     global last_recorded_time
#     219
# --> 220     with renderer.draw_loop():
#     221         if looping or redraw:
#     222             builtins.frame_count += 1
#
# c:\program files\python35\lib\contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# c:\program files\python35\lib\site-packages\p5\opengl\renderer.py in draw_loop()
#     277     """
#     278     global transform_matrix
# --> 279     gl.glViewport(*viewport)
#     280     transform_matrix = np.identity(4)
#     281
#
# c:\program files\python35\lib\site-packages\OpenGL\error.py in glCheckError(self, result, baseOperation, cArguments, *args)
#     230                         result,
#     231                         cArguments = cArguments,
# --> 232                         baseOperation = baseOperation,
#     233                     )
#     234                 return result
#
# GLError: GLError(
# 	err = 1282,
# 	description = b'invalid operation',
# 	baseOperation = glViewport,
# 	cArguments = (0, 0, 400, 300)
# )
# ---------------------------------------------------------------------------
# GLError                                   Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# c:\program files\python35\lib\site-packages\pyglet\app\win32.py in _timer_proc_func(self, hwnd, msg, timer, t)
#     146     def _timer_proc_func(self, hwnd, msg, timer, t):
#     147         if self._timer_func:
# --> 148             self._timer_func()
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in _blocking_timer(self)
#     243
#     244     def _blocking_timer(self):
# --> 245         timeout = self.idle()
#     246         app.platform_event_loop.set_timer(self._blocking_timer, timeout)
#     247
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in idle(self)
#     272         '''
#     273         dt = self.clock.update_time()
# --> 274         redraw_all = self.clock.call_scheduled_functions(dt)
#     275
#     276         # Redraw all windows
#
# c:\program files\python35\lib\site-packages\pyglet\clock.py in call_scheduled_functions(self, dt)
#     307                 break
#     308             result = True
# --> 309             item.func(ts - item.last_ts, *item.args, **item.kwargs)
#     310             if item.interval:
#     311                 # Try to keep timing regular, even if overslept this time;
#
# c:\program files\python35\lib\site-packages\p5\sketch\base.py in update(dt)
#     218     global last_recorded_time
#     219
# --> 220     with renderer.draw_loop():
#     221         if looping or redraw:
#     222             builtins.frame_count += 1
#
# c:\program files\python35\lib\contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# c:\program files\python35\lib\site-packages\p5\opengl\renderer.py in draw_loop()
#     277     """
#     278     global transform_matrix
# --> 279     gl.glViewport(*viewport)
#     280     transform_matrix = np.identity(4)
#     281
#
# c:\program files\python35\lib\site-packages\OpenGL\error.py in glCheckError(self, result, baseOperation, cArguments, *args)
#     230                         result,
#     231                         cArguments = cArguments,
# --> 232                         baseOperation = baseOperation,
#     233                     )
#     234                 return result
#
# GLError: GLError(
# 	err = 1282,
# 	description = b'invalid operation',
# 	baseOperation = glViewport,
# 	cArguments = (0, 0, 400, 300)
# )
# ---------------------------------------------------------------------------
# GLError                                   Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# c:\program files\python35\lib\site-packages\pyglet\app\win32.py in _timer_proc_func(self, hwnd, msg, timer, t)
#     146     def _timer_proc_func(self, hwnd, msg, timer, t):
#     147         if self._timer_func:
# --> 148             self._timer_func()
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in _blocking_timer(self)
#     243
#     244     def _blocking_timer(self):
# --> 245         timeout = self.idle()
#     246         app.platform_event_loop.set_timer(self._blocking_timer, timeout)
#     247
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in idle(self)
#     272         '''
#     273         dt = self.clock.update_time()
# --> 274         redraw_all = self.clock.call_scheduled_functions(dt)
#     275
#     276         # Redraw all windows
#
# c:\program files\python35\lib\site-packages\pyglet\clock.py in call_scheduled_functions(self, dt)
#     307                 break
#     308             result = True
# --> 309             item.func(ts - item.last_ts, *item.args, **item.kwargs)
#     310             if item.interval:
#     311                 # Try to keep timing regular, even if overslept this time;
#
# c:\program files\python35\lib\site-packages\p5\sketch\base.py in update(dt)
#     218     global last_recorded_time
#     219
# --> 220     with renderer.draw_loop():
#     221         if looping or redraw:
#     222             builtins.frame_count += 1
#
# c:\program files\python35\lib\contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# c:\program files\python35\lib\site-packages\p5\opengl\renderer.py in draw_loop()
#     277     """
#     278     global transform_matrix
# --> 279     gl.glViewport(*viewport)
#     280     transform_matrix = np.identity(4)
#     281
#
# c:\program files\python35\lib\site-packages\OpenGL\error.py in glCheckError(self, result, baseOperation, cArguments, *args)
#     230                         result,
#     231                         cArguments = cArguments,
# --> 232                         baseOperation = baseOperation,
#     233                     )
#     234                 return result
#
# GLError: GLError(
# 	err = 1282,
# 	description = b'invalid operation',
# 	baseOperation = glViewport,
# 	cArguments = (0, 0, 400, 300)
# )
# ---------------------------------------------------------------------------
# GLError                                   Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# c:\program files\python35\lib\site-packages\pyglet\app\win32.py in _timer_proc_func(self, hwnd, msg, timer, t)
#     146     def _timer_proc_func(self, hwnd, msg, timer, t):
#     147         if self._timer_func:
# --> 148             self._timer_func()
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in _blocking_timer(self)
#     243
#     244     def _blocking_timer(self):
# --> 245         timeout = self.idle()
#     246         app.platform_event_loop.set_timer(self._blocking_timer, timeout)
#     247
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in idle(self)
#     272         '''
#     273         dt = self.clock.update_time()
# --> 274         redraw_all = self.clock.call_scheduled_functions(dt)
#     275
#     276         # Redraw all windows
#
# c:\program files\python35\lib\site-packages\pyglet\clock.py in call_scheduled_functions(self, dt)
#     307                 break
#     308             result = True
# --> 309             item.func(ts - item.last_ts, *item.args, **item.kwargs)
#     310             if item.interval:
#     311                 # Try to keep timing regular, even if overslept this time;
#
# c:\program files\python35\lib\site-packages\p5\sketch\base.py in update(dt)
#     218     global last_recorded_time
#     219
# --> 220     with renderer.draw_loop():
#     221         if looping or redraw:
#     222             builtins.frame_count += 1
#
# c:\program files\python35\lib\contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# c:\program files\python35\lib\site-packages\p5\opengl\renderer.py in draw_loop()
#     277     """
#     278     global transform_matrix
# --> 279     gl.glViewport(*viewport)
#     280     transform_matrix = np.identity(4)
#     281
#
# c:\program files\python35\lib\site-packages\OpenGL\error.py in glCheckError(self, result, baseOperation, cArguments, *args)
#     230                         result,
#     231                         cArguments = cArguments,
# --> 232                         baseOperation = baseOperation,
#     233                     )
#     234                 return result
#
# GLError: GLError(
# 	err = 1282,
# 	description = b'invalid operation',
# 	baseOperation = glViewport,
# 	cArguments = (0, 0, 400, 300)
# )
# ---------------------------------------------------------------------------
# GLError                                   Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# c:\program files\python35\lib\site-packages\pyglet\app\win32.py in _timer_proc_func(self, hwnd, msg, timer, t)
#     146     def _timer_proc_func(self, hwnd, msg, timer, t):
#     147         if self._timer_func:
# --> 148             self._timer_func()
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in _blocking_timer(self)
#     243
#     244     def _blocking_timer(self):
# --> 245         timeout = self.idle()
#     246         app.platform_event_loop.set_timer(self._blocking_timer, timeout)
#     247
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in idle(self)
#     272         '''
#     273         dt = self.clock.update_time()
# --> 274         redraw_all = self.clock.call_scheduled_functions(dt)
#     275
#     276         # Redraw all windows
#
# c:\program files\python35\lib\site-packages\pyglet\clock.py in call_scheduled_functions(self, dt)
#     307                 break
#     308             result = True
# --> 309             item.func(ts - item.last_ts, *item.args, **item.kwargs)
#     310             if item.interval:
#     311                 # Try to keep timing regular, even if overslept this time;
#
# c:\program files\python35\lib\site-packages\p5\sketch\base.py in update(dt)
#     218     global last_recorded_time
#     219
# --> 220     with renderer.draw_loop():
#     221         if looping or redraw:
#     222             builtins.frame_count += 1
#
# c:\program files\python35\lib\contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# c:\program files\python35\lib\site-packages\p5\opengl\renderer.py in draw_loop()
#     277     """
#     278     global transform_matrix
# --> 279     gl.glViewport(*viewport)
#     280     transform_matrix = np.identity(4)
#     281
#
# c:\program files\python35\lib\site-packages\OpenGL\error.py in glCheckError(self, result, baseOperation, cArguments, *args)
#     230                         result,
#     231                         cArguments = cArguments,
# --> 232                         baseOperation = baseOperation,
#     233                     )
#     234                 return result
#
# GLError: GLError(
# 	err = 1282,
# 	description = b'invalid operation',
# 	baseOperation = glViewport,
# 	cArguments = (0, 0, 400, 300)
# )
# ---------------------------------------------------------------------------
# GLError                                   Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# c:\program files\python35\lib\site-packages\pyglet\app\win32.py in _timer_proc_func(self, hwnd, msg, timer, t)
#     146     def _timer_proc_func(self, hwnd, msg, timer, t):
#     147         if self._timer_func:
# --> 148             self._timer_func()
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in _blocking_timer(self)
#     243
#     244     def _blocking_timer(self):
# --> 245         timeout = self.idle()
#     246         app.platform_event_loop.set_timer(self._blocking_timer, timeout)
#     247
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in idle(self)
#     272         '''
#     273         dt = self.clock.update_time()
# --> 274         redraw_all = self.clock.call_scheduled_functions(dt)
#     275
#     276         # Redraw all windows
#
# c:\program files\python35\lib\site-packages\pyglet\clock.py in call_scheduled_functions(self, dt)
#     307                 break
#     308             result = True
# --> 309             item.func(ts - item.last_ts, *item.args, **item.kwargs)
#     310             if item.interval:
#     311                 # Try to keep timing regular, even if overslept this time;
#
# c:\program files\python35\lib\site-packages\p5\sketch\base.py in update(dt)
#     218     global last_recorded_time
#     219
# --> 220     with renderer.draw_loop():
#     221         if looping or redraw:
#     222             builtins.frame_count += 1
#
# c:\program files\python35\lib\contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# c:\program files\python35\lib\site-packages\p5\opengl\renderer.py in draw_loop()
#     277     """
#     278     global transform_matrix
# --> 279     gl.glViewport(*viewport)
#     280     transform_matrix = np.identity(4)
#     281
#
# c:\program files\python35\lib\site-packages\OpenGL\error.py in glCheckError(self, result, baseOperation, cArguments, *args)
#     230                         result,
#     231                         cArguments = cArguments,
# --> 232                         baseOperation = baseOperation,
#     233                     )
#     234                 return result
#
# GLError: GLError(
# 	err = 1282,
# 	description = b'invalid operation',
# 	baseOperation = glViewport,
# 	cArguments = (0, 0, 400, 300)
# )
# ---------------------------------------------------------------------------
# GLError                                   Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# c:\program files\python35\lib\site-packages\pyglet\app\win32.py in _timer_proc_func(self, hwnd, msg, timer, t)
#     146     def _timer_proc_func(self, hwnd, msg, timer, t):
#     147         if self._timer_func:
# --> 148             self._timer_func()
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in _blocking_timer(self)
#     243
#     244     def _blocking_timer(self):
# --> 245         timeout = self.idle()
#     246         app.platform_event_loop.set_timer(self._blocking_timer, timeout)
#     247
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in idle(self)
#     272         '''
#     273         dt = self.clock.update_time()
# --> 274         redraw_all = self.clock.call_scheduled_functions(dt)
#     275
#     276         # Redraw all windows
#
# c:\program files\python35\lib\site-packages\pyglet\clock.py in call_scheduled_functions(self, dt)
#     307                 break
#     308             result = True
# --> 309             item.func(ts - item.last_ts, *item.args, **item.kwargs)
#     310             if item.interval:
#     311                 # Try to keep timing regular, even if overslept this time;
#
# c:\program files\python35\lib\site-packages\p5\sketch\base.py in update(dt)
#     218     global last_recorded_time
#     219
# --> 220     with renderer.draw_loop():
#     221         if looping or redraw:
#     222             builtins.frame_count += 1
#
# c:\program files\python35\lib\contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# c:\program files\python35\lib\site-packages\p5\opengl\renderer.py in draw_loop()
#     277     """
#     278     global transform_matrix
# --> 279     gl.glViewport(*viewport)
#     280     transform_matrix = np.identity(4)
#     281
#
# c:\program files\python35\lib\site-packages\OpenGL\error.py in glCheckError(self, result, baseOperation, cArguments, *args)
#     230                         result,
#     231                         cArguments = cArguments,
# --> 232                         baseOperation = baseOperation,
#     233                     )
#     234                 return result
#
# GLError: GLError(
# 	err = 1282,
# 	description = b'invalid operation',
# 	baseOperation = glViewport,
# 	cArguments = (0, 0, 400, 300)
# )
# ---------------------------------------------------------------------------
# GLError                                   Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# c:\program files\python35\lib\site-packages\pyglet\app\win32.py in _timer_proc_func(self, hwnd, msg, timer, t)
#     146     def _timer_proc_func(self, hwnd, msg, timer, t):
#     147         if self._timer_func:
# --> 148             self._timer_func()
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in _blocking_timer(self)
#     243
#     244     def _blocking_timer(self):
# --> 245         timeout = self.idle()
#     246         app.platform_event_loop.set_timer(self._blocking_timer, timeout)
#     247
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in idle(self)
#     272         '''
#     273         dt = self.clock.update_time()
# --> 274         redraw_all = self.clock.call_scheduled_functions(dt)
#     275
#     276         # Redraw all windows
#
# c:\program files\python35\lib\site-packages\pyglet\clock.py in call_scheduled_functions(self, dt)
#     307                 break
#     308             result = True
# --> 309             item.func(ts - item.last_ts, *item.args, **item.kwargs)
#     310             if item.interval:
#     311                 # Try to keep timing regular, even if overslept this time;
#
# c:\program files\python35\lib\site-packages\p5\sketch\base.py in update(dt)
#     218     global last_recorded_time
#     219
# --> 220     with renderer.draw_loop():
#     221         if looping or redraw:
#     222             builtins.frame_count += 1
#
# c:\program files\python35\lib\contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# c:\program files\python35\lib\site-packages\p5\opengl\renderer.py in draw_loop()
#     277     """
#     278     global transform_matrix
# --> 279     gl.glViewport(*viewport)
#     280     transform_matrix = np.identity(4)
#     281
#
# c:\program files\python35\lib\site-packages\OpenGL\error.py in glCheckError(self, result, baseOperation, cArguments, *args)
#     230                         result,
#     231                         cArguments = cArguments,
# --> 232                         baseOperation = baseOperation,
#     233                     )
#     234                 return result
#
# GLError: GLError(
# 	err = 1282,
# 	description = b'invalid operation',
# 	baseOperation = glViewport,
# 	cArguments = (0, 0, 400, 300)
# )
# ---------------------------------------------------------------------------
# GLError                                   Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# c:\program files\python35\lib\site-packages\pyglet\app\win32.py in _timer_proc_func(self, hwnd, msg, timer, t)
#     146     def _timer_proc_func(self, hwnd, msg, timer, t):
#     147         if self._timer_func:
# --> 148             self._timer_func()
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in _blocking_timer(self)
#     243
#     244     def _blocking_timer(self):
# --> 245         timeout = self.idle()
#     246         app.platform_event_loop.set_timer(self._blocking_timer, timeout)
#     247
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in idle(self)
#     272         '''
#     273         dt = self.clock.update_time()
# --> 274         redraw_all = self.clock.call_scheduled_functions(dt)
#     275
#     276         # Redraw all windows
#
# c:\program files\python35\lib\site-packages\pyglet\clock.py in call_scheduled_functions(self, dt)
#     307                 break
#     308             result = True
# --> 309             item.func(ts - item.last_ts, *item.args, **item.kwargs)
#     310             if item.interval:
#     311                 # Try to keep timing regular, even if overslept this time;
#
# c:\program files\python35\lib\site-packages\p5\sketch\base.py in update(dt)
#     218     global last_recorded_time
#     219
# --> 220     with renderer.draw_loop():
#     221         if looping or redraw:
#     222             builtins.frame_count += 1
#
# c:\program files\python35\lib\contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
# ...
# --> 279     gl.glViewport(*viewport)
#     280     transform_matrix = np.identity(4)
#     281
#
# c:\program files\python35\lib\site-packages\OpenGL\error.py in glCheckError(self, result, baseOperation, cArguments, *args)
#     230                         result,
#     231                         cArguments = cArguments,
# --> 232                         baseOperation = baseOperation,
#     233                     )
#     234                 return result
#
# GLError: GLError(
# 	err = 1282,
# 	description = b'invalid operation',
# 	baseOperation = glViewport,
# 	cArguments = (0, 0, 400, 300)
# )
# ---------------------------------------------------------------------------
# GLError                                   Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# c:\program files\python35\lib\site-packages\pyglet\app\win32.py in _timer_proc_func(self, hwnd, msg, timer, t)
#     146     def _timer_proc_func(self, hwnd, msg, timer, t):
#     147         if self._timer_func:
# --> 148             self._timer_func()
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in _blocking_timer(self)
#     243
#     244     def _blocking_timer(self):
# --> 245         timeout = self.idle()
#     246         app.platform_event_loop.set_timer(self._blocking_timer, timeout)
#     247
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in idle(self)
#     272         '''
#     273         dt = self.clock.update_time()
# --> 274         redraw_all = self.clock.call_scheduled_functions(dt)
#     275
#     276         # Redraw all windows
#
# c:\program files\python35\lib\site-packages\pyglet\clock.py in call_scheduled_functions(self, dt)
#     307                 break
#     308             result = True
# --> 309             item.func(ts - item.last_ts, *item.args, **item.kwargs)
#     310             if item.interval:
#     311                 # Try to keep timing regular, even if overslept this time;
#
# c:\program files\python35\lib\site-packages\p5\sketch\base.py in update(dt)
#     218     global last_recorded_time
#     219
# --> 220     with renderer.draw_loop():
#     221         if looping or redraw:
#     222             builtins.frame_count += 1
#
# c:\program files\python35\lib\contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# c:\program files\python35\lib\site-packages\p5\opengl\renderer.py in draw_loop()
#     277     """
#     278     global transform_matrix
# --> 279     gl.glViewport(*viewport)
#     280     transform_matrix = np.identity(4)
#     281
#
# c:\program files\python35\lib\site-packages\OpenGL\error.py in glCheckError(self, result, baseOperation, cArguments, *args)
#     230                         result,
#     231                         cArguments = cArguments,
# --> 232                         baseOperation = baseOperation,
#     233                     )
#     234                 return result
#
# GLError: GLError(
# 	err = 1282,
# 	description = b'invalid operation',
# 	baseOperation = glViewport,
# 	cArguments = (0, 0, 400, 300)
# )
# ---------------------------------------------------------------------------
# GLError                                   Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# c:\program files\python35\lib\site-packages\pyglet\app\win32.py in _timer_proc_func(self, hwnd, msg, timer, t)
#     146     def _timer_proc_func(self, hwnd, msg, timer, t):
#     147         if self._timer_func:
# --> 148             self._timer_func()
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in _blocking_timer(self)
#     243
#     244     def _blocking_timer(self):
# --> 245         timeout = self.idle()
#     246         app.platform_event_loop.set_timer(self._blocking_timer, timeout)
#     247
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in idle(self)
#     272         '''
#     273         dt = self.clock.update_time()
# --> 274         redraw_all = self.clock.call_scheduled_functions(dt)
#     275
#     276         # Redraw all windows
#
# c:\program files\python35\lib\site-packages\pyglet\clock.py in call_scheduled_functions(self, dt)
#     307                 break
#     308             result = True
# --> 309             item.func(ts - item.last_ts, *item.args, **item.kwargs)
#     310             if item.interval:
#     311                 # Try to keep timing regular, even if overslept this time;
#
# c:\program files\python35\lib\site-packages\p5\sketch\base.py in update(dt)
#     218     global last_recorded_time
#     219
# --> 220     with renderer.draw_loop():
#     221         if looping or redraw:
#     222             builtins.frame_count += 1
#
# c:\program files\python35\lib\contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# c:\program files\python35\lib\site-packages\p5\opengl\renderer.py in draw_loop()
#     277     """
#     278     global transform_matrix
# --> 279     gl.glViewport(*viewport)
#     280     transform_matrix = np.identity(4)
#     281
#
# c:\program files\python35\lib\site-packages\OpenGL\error.py in glCheckError(self, result, baseOperation, cArguments, *args)
#     230                         result,
#     231                         cArguments = cArguments,
# --> 232                         baseOperation = baseOperation,
#     233                     )
#     234                 return result
#
# GLError: GLError(
# 	err = 1282,
# 	description = b'invalid operation',
# 	baseOperation = glViewport,
# 	cArguments = (0, 0, 400, 300)
# )
# ---------------------------------------------------------------------------
# GLError                                   Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# c:\program files\python35\lib\site-packages\pyglet\app\win32.py in _timer_proc_func(self, hwnd, msg, timer, t)
#     146     def _timer_proc_func(self, hwnd, msg, timer, t):
#     147         if self._timer_func:
# --> 148             self._timer_func()
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in _blocking_timer(self)
#     243
#     244     def _blocking_timer(self):
# --> 245         timeout = self.idle()
#     246         app.platform_event_loop.set_timer(self._blocking_timer, timeout)
#     247
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in idle(self)
#     272         '''
#     273         dt = self.clock.update_time()
# --> 274         redraw_all = self.clock.call_scheduled_functions(dt)
#     275
#     276         # Redraw all windows
#
# c:\program files\python35\lib\site-packages\pyglet\clock.py in call_scheduled_functions(self, dt)
#     307                 break
#     308             result = True
# --> 309             item.func(ts - item.last_ts, *item.args, **item.kwargs)
#     310             if item.interval:
#     311                 # Try to keep timing regular, even if overslept this time;
#
# c:\program files\python35\lib\site-packages\p5\sketch\base.py in update(dt)
#     218     global last_recorded_time
#     219
# --> 220     with renderer.draw_loop():
#     221         if looping or redraw:
#     222             builtins.frame_count += 1
#
# c:\program files\python35\lib\contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# c:\program files\python35\lib\site-packages\p5\opengl\renderer.py in draw_loop()
#     277     """
#     278     global transform_matrix
# --> 279     gl.glViewport(*viewport)
#     280     transform_matrix = np.identity(4)
#     281
#
# c:\program files\python35\lib\site-packages\OpenGL\error.py in glCheckError(self, result, baseOperation, cArguments, *args)
#     230                         result,
#     231                         cArguments = cArguments,
# --> 232                         baseOperation = baseOperation,
#     233                     )
#     234                 return result
#
# GLError: GLError(
# 	err = 1282,
# 	description = b'invalid operation',
# 	baseOperation = glViewport,
# 	cArguments = (0, 0, 400, 300)
# )
# ---------------------------------------------------------------------------
# GLError                                   Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# c:\program files\python35\lib\site-packages\pyglet\app\win32.py in _timer_proc_func(self, hwnd, msg, timer, t)
#     146     def _timer_proc_func(self, hwnd, msg, timer, t):
#     147         if self._timer_func:
# --> 148             self._timer_func()
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in _blocking_timer(self)
#     243
#     244     def _blocking_timer(self):
# --> 245         timeout = self.idle()
#     246         app.platform_event_loop.set_timer(self._blocking_timer, timeout)
#     247
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in idle(self)
#     272         '''
#     273         dt = self.clock.update_time()
# --> 274         redraw_all = self.clock.call_scheduled_functions(dt)
#     275
#     276         # Redraw all windows
#
# c:\program files\python35\lib\site-packages\pyglet\clock.py in call_scheduled_functions(self, dt)
#     307                 break
#     308             result = True
# --> 309             item.func(ts - item.last_ts, *item.args, **item.kwargs)
#     310             if item.interval:
#     311                 # Try to keep timing regular, even if overslept this time;
#
# c:\program files\python35\lib\site-packages\p5\sketch\base.py in update(dt)
#     218     global last_recorded_time
#     219
# --> 220     with renderer.draw_loop():
#     221         if looping or redraw:
#     222             builtins.frame_count += 1
#
# c:\program files\python35\lib\contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# c:\program files\python35\lib\site-packages\p5\opengl\renderer.py in draw_loop()
#     277     """
#     278     global transform_matrix
# --> 279     gl.glViewport(*viewport)
#     280     transform_matrix = np.identity(4)
#     281
#
# c:\program files\python35\lib\site-packages\OpenGL\error.py in glCheckError(self, result, baseOperation, cArguments, *args)
#     230                         result,
#     231                         cArguments = cArguments,
# --> 232                         baseOperation = baseOperation,
#     233                     )
#     234                 return result
#
# GLError: GLError(
# 	err = 1282,
# 	description = b'invalid operation',
# 	baseOperation = glViewport,
# 	cArguments = (0, 0, 400, 300)
# )
# ---------------------------------------------------------------------------
# GLError                                   Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# c:\program files\python35\lib\site-packages\pyglet\app\win32.py in _timer_proc_func(self, hwnd, msg, timer, t)
#     146     def _timer_proc_func(self, hwnd, msg, timer, t):
#     147         if self._timer_func:
# --> 148             self._timer_func()
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in _blocking_timer(self)
#     243
#     244     def _blocking_timer(self):
# --> 245         timeout = self.idle()
#     246         app.platform_event_loop.set_timer(self._blocking_timer, timeout)
#     247
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in idle(self)
#     272         '''
#     273         dt = self.clock.update_time()
# --> 274         redraw_all = self.clock.call_scheduled_functions(dt)
#     275
#     276         # Redraw all windows
#
# c:\program files\python35\lib\site-packages\pyglet\clock.py in call_scheduled_functions(self, dt)
#     307                 break
#     308             result = True
# --> 309             item.func(ts - item.last_ts, *item.args, **item.kwargs)
#     310             if item.interval:
#     311                 # Try to keep timing regular, even if overslept this time;
#
# c:\program files\python35\lib\site-packages\p5\sketch\base.py in update(dt)
#     218     global last_recorded_time
#     219
# --> 220     with renderer.draw_loop():
#     221         if looping or redraw:
#     222             builtins.frame_count += 1
#
# c:\program files\python35\lib\contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# c:\program files\python35\lib\site-packages\p5\opengl\renderer.py in draw_loop()
#     277     """
#     278     global transform_matrix
# --> 279     gl.glViewport(*viewport)
#     280     transform_matrix = np.identity(4)
#     281
#
# c:\program files\python35\lib\site-packages\OpenGL\error.py in glCheckError(self, result, baseOperation, cArguments, *args)
#     230                         result,
#     231                         cArguments = cArguments,
# --> 232                         baseOperation = baseOperation,
#     233                     )
#     234                 return result
#
# GLError: GLError(
# 	err = 1282,
# 	description = b'invalid operation',
# 	baseOperation = glViewport,
# 	cArguments = (0, 0, 400, 300)
# )
# ---------------------------------------------------------------------------
# GLError                                   Traceback (most recent call last)
# _ctypes/callbacks.c in 'calling callback function'()
#
# c:\program files\python35\lib\site-packages\pyglet\app\win32.py in _timer_proc_func(self, hwnd, msg, timer, t)
#     146     def _timer_proc_func(self, hwnd, msg, timer, t):
#     147         if self._timer_func:
# --> 148             self._timer_func()
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in _blocking_timer(self)
#     243
#     244     def _blocking_timer(self):
# --> 245         timeout = self.idle()
#     246         app.platform_event_loop.set_timer(self._blocking_timer, timeout)
#     247
#
# c:\program files\python35\lib\site-packages\pyglet\app\base.py in idle(self)
#     272         '''
#     273         dt = self.clock.update_time()
# --> 274         redraw_all = self.clock.call_scheduled_functions(dt)
#     275
#     276         # Redraw all windows
#
# c:\program files\python35\lib\site-packages\pyglet\clock.py in call_scheduled_functions(self, dt)
#     307                 break
#     308             result = True
# --> 309             item.func(ts - item.last_ts, *item.args, **item.kwargs)
#     310             if item.interval:
#     311                 # Try to keep timing regular, even if overslept this time;
#
# c:\program files\python35\lib\site-packages\p5\sketch\base.py in update(dt)
#     218     global last_recorded_time
#     219
# --> 220     with renderer.draw_loop():
#     221         if looping or redraw:
#     222             builtins.frame_count += 1
#
# c:\program files\python35\lib\contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# c:\program files\python35\lib\site-packages\p5\opengl\renderer.py in draw_loop()
#     277     """
#     278     global transform_matrix
# --> 279     gl.glViewport(*viewport)
#     280     transform_matrix = np.identity(4)
#     281
#
# c:\program files\python35\lib\site-packages\OpenGL\error.py in glCheckError(self, result, baseOperation, cArguments, *args)
#     230                         result,
#     231                         cArguments = cArguments,
# --> 232                         baseOperation = baseOperation,
#     233                     )
#     234                 return result
#
# GLError: GLError(
# 	err = 1282,
# 	description = b'invalid operation',
# 	baseOperation = glViewport,
# 	cArguments = (0, 0, 400, 300)
# )

# %% [markdown]
# #### วาดเส้น
# color - ระดับสีขาวดำ <br/>
# rgb   - สี red green blue

# %%
stroke(color)
stroke(r, g, b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-64a5d82734f8> in <module>()
# ----> 1 stroke(color)
#       2 stroke(r, g, b)
#
# c:\program files\python35\lib\site-packages\p5\core\attribs.py in stroke(*color_args, **color_kwargs)
#      65     :rtype: Color
#      66     """
# ---> 67     stroke_color = Color(*color_args, **color_kwargs)
#      68     renderer.stroke_enabled = True
#      69     renderer.stroke_color = stroke_color.normalized
#
# c:\program files\python35\lib\site-packages\p5\core\color.py in __init__(self, color_mode, *args, **kwargs)
#     161            a = args[0]._alpha
#     162         else:
# --> 163             r, g, b, a = parse_color(*args, color_mode=color_mode, **kwargs)
#     164
#     165         self._red = r
#
# c:\program files\python35\lib\site-packages\p5\core\color.py in parse_color(color_mode, *args, **kwargs)
#     142     if not (rgb is None):
#     143         r, g, b = rgb
# --> 144         red = constrain(r / color_range[0], 0, 1)
#     145         green = constrain(g / color_range[1], 0, 1)
#     146         blue = constrain(b / color_range[2], 0, 1)
#
# TypeError: unsupported operand type(s) for /: 'module' and 'int'

# %% [markdown]
# #### เติมสี
# color - ระดับสีขาวดำ <br/>
# rgb   - สี red green blue

# %%
fill(color)
fill(r, g, b)

# %% [markdown]
# #### จุด

# %%
point(x, y)

# %% [markdown]
# #### เส้น
# จุดที่หนึ่ง (x1, y1) <br/>
# จุดที่สอง (x2, y2)

# %%
line((x1, y1), (x2, y2))

# %% [markdown]
# #### สีเหลี่ยม
# จุดมุม (x, y) <br/>
# width กว้าง <br/>
# height สูง

# %%
rect((x, y) , width, height)

# %% [markdown]
# #### วงรี (วงกลม)
# จุดศูนย์กลาง (x, y) <br/>
# width กว้าง <br/>
# height สูง

# %%
ellipse((x, y) , width, height)
